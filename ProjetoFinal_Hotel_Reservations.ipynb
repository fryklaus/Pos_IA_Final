# %% [markdown]
# # Projeto Final
# ## Base de dados **Hotel Reservations**
# - https://www.kaggle.com/datasets/ahsan81/hotel-reservations-classification-dataset
#
# #### Submissão: [Google-Forms](https://forms.gle/kKjVGvuboHb4LD4S9)
# #### Prazo de envio: **09/12/2024**

# %% [markdown]
# ## Exercício 1: Utilizando a função apply
# Crie uma nova coluna chamada `stay_duration` a partir da soma de `no_of_weekend_nights` e `no_of_week_nights`.

# %%
import kagglehub
import pandas as pd
#Baixando direto do kaggle
path = kagglehub.dataset_download("ahsan81/hotel-reservations-classification-dataset")

#Importando o arquivo
df = pd.read_csv(f'{path}/Hotel Reservations.csv')
#Criar a coluna somando o número de dias da semana e finais de semana com apply
df['stay_duration'] = df.apply(lambda row: row['no_of_weekend_nights'] + row['no_of_week_nights'], axis=1)
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %% [markdown]
# ## Exercício 2: Utilizando a função transform
# - Aplique a normalização (escalonamento entre 0 e 1) Min-Max na coluna `avg_price_per_room`.
# - **Normalização Min-Max**:
# $
# x' = \frac{x - x_{\text{min}}}{x_{\text{max}} - x_{\text{min}}}
# $
#
# ### Onde:
# - \( $x$ \): Valor original.
# - \( $x'$ \): Valor normalizado (entre 0 e 1).
# - \( $x_{\text{min}}$ \): Valor mínimo do conjunto de dados.
# - \( $x_{\text{max}}$ \): Valor máximo do conjunto de dados.

# %%
#Importando o arquivo
df = pd.read_csv(f'{path}/Hotel Reservations.csv')
#Normalizando utilizando o transform e a Lambda e jogando em outra coluna
df['preco_medio_normalizado'] = df['avg_price_per_room'].transform(lambda avg: (avg - avg.min()) / (avg.max() - avg.min()))
#Exibindo o DF
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %% [markdown]
# ## Exercício 3: Substituições com replace e regex
# Altere a coluna `room_type_reserved` extraindo apenas os números da coluna.

# %%
#Importando o arquivo
df = pd.read_csv(f'{path}/Hotel Reservations.csv')
#Normalizando utilizando o transform e a Lambda e jogando em outra coluna
df['room_type_reserved'] = df['room_type_reserved'].replace({r'\D':''},regex=True)
#Exibindo o DF
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %% [markdown]
# ## Exercício 4: Gráfico Mapa de Calor
# Faça a plotagem do Mapa de calor (**Heatmap**) entre as colunas numéricas

# %%
#Importando o arquivo
df = pd.read_csv(f'{path}/Hotel Reservations.csv')
import seaborn as sns
import matplotlib.pyplot as plt

#Busca só colunas numéricas
corr = df.select_dtypes(include=['number']).corr()
#Tirei os números pq tava muito bagunçado
sns.heatmap(corr,annot=False,cmap='coolwarm')
#Título
plt.title('Mapa de Calor')
#Mostrar
plt.show()

# %% [markdown]
# ## Exercício 5: Expressões Regulares
# Altere a coluna `Booking_ID`, extraindo apenas os números da coluna.

# %%
#Importando o arquivo
df = pd.read_csv(f'{path}/Hotel Reservations.csv')
# Expressão regular para inteiros e decimais
df['Booking_ID'] = df['Booking_ID'].str.extract(r'(\d+\.?\d*)')
#Mostra o df
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0          00001             2               0                     1
# 1          00002             2               0                     2
# 2          00003             1               0                     2
# 3          00004             2               0                     0
# 4          00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270      36271             3               0                     2
# 36271      36272             2               0                     1
# 36272      36273             2               0                     2
# 36273      36274             2               0                     0
# 36274      36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %% [markdown]
# ## Exercício 6: Gráfico de Dispersão
# Faça a plotagem com a relação entre `lead_time` e `avg_price_per_room` (sem a normalização).

# %%
#Importando o arquivo
df = pd.read_csv(f'{path}/Hotel Reservations.csv')
import seaborn as sns
import matplotlib.pyplot as plt
#Apenas relacionando as duas colunas conforme solicitado
sns.scatterplot(data=df, x='lead_time', y='avg_price_per_room')
plt.show()

# %% [markdown]
# ## Exercício 7: Groupby e Agg
# Calcule o preço médio (`avg_price_per_room`), sem normalização, por tipo de quarto (`room_type_reserved`).

# %%
#Importando o arquivo
df = pd.read_csv(f'{path}/Hotel Reservations.csv')
#calculando o preço médio por quarto
preco_medio_por_tipo = df.groupby('room_type_reserved').agg(preco_medio=('avg_price_per_room', 'mean'))
#Mergeando os dados
df = df.merge(preco_medio_por_tipo, on='room_type_reserved', how='left')
#Mostra o df agrupado pra ficar mais bonito de ver
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %% [markdown]
# ## Exercício 8: Boxplot
# Apresente o boxplot com os dados de preço médio (`avg_price_per_room`), sem normalização, por tipo de quarto (`room_type_reserved`).

# %%
#Importando o arquivo
df = pd.read_csv(f'{path}/Hotel Reservations.csv')
#Aumentar o tamanho do gráfico pra não zoar a parada, pq senão fica zoado
plt.figure(figsize=(11, 6))
#Criando o boxplot
sns.boxplot(data=df, x='room_type_reserved', y='avg_price_per_room')
plt.title('Preço Médio por Tipo de Quarto')
plt.xlabel('Tipo de Quarto')
plt.ylabel('Preço Médio')
plt.show()
